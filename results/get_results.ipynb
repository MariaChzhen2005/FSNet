# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os 

# Define a function to load and parse test result files
def load_test_results(file_path_prefix):
    try:
        # Get the directory from the file path prefix
        directory = os.path.dirname(file_path_prefix)
        # Get the base filename from the file path prefix
        base_filename = os.path.basename(file_path_prefix)

        # Find the file that starts with the base filename
        matching_files = [f for f in os.listdir(directory) if f.startswith(base_filename)]

        if not matching_files:
            print(f"Error: No file found in {directory} starting with {base_filename}")
            return None

        # Assuming only one file matches the prefix
        file_path = os.path.join(directory, matching_files[0])

        with open(file_path, 'r') as f:
            data = json.load(f)
        return data
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def calculate_stats(results):
    """
    Calculates and prints statistics for results.

    Args:
        results (dict): Dictionary containing results.
    """
    eq_vio = results['test_eq_violation']
    ineq_vio = results['test_ineq_violation']
    
    eq_vio_mean = np.mean(eq_vio)
    eq_vio_std = np.std(eq_vio)
    eq_vio_max = np.max(eq_vio)
    
    ineq_vio_mean = np.mean(ineq_vio)
    ineq_vio_std = np.std(ineq_vio)
    ineq_vio_max = np.max(ineq_vio)
    
    opt_gap = results['opt_gap']

    opt_gap_mean = 100*np.mean(opt_gap)
    opt_gap_std = 100*np.std(opt_gap)
    opt_gap_min = 100*np.min(opt_gap)
    opt_gap_max = 100*np.max(opt_gap)
    
    time = results['test_time']
    time_mean = np.mean(time)
    
    
    print("Constraint Violation Statistics:")
    print(f"Eq violation: {eq_vio_mean:.1e} ± {eq_vio_std:.1e}")
    print(f"Max eq violation: {eq_vio_max:.1e}") 
    print(f"Ineq violation: {ineq_vio_mean:.1e} ± {ineq_vio_std:.1e}")
    print(f"Max ineq violation: {ineq_vio_max:.1e}")

    print("\nOptimality Gap Statistics:")
    print(f"Mean opt gap: {opt_gap_mean:.3f} ± {opt_gap_std:.3f}")
    print(f"Min opt gap: {opt_gap_min:.3f}")
    print(f"Max opt gap: {opt_gap_max:.3f}")

    print("\nTime Statistics:")
    print(f"Total time: {time_mean:.3f}")

# %%
method = "adaptive_penalty"
prob_type = "nonsmooth_nonconvex"
prob_name = "qcqp"
seed = 2025
batch = 2000
dir_path = f"{prob_type}/{prob_name}/{prob_name.upper()}Problem-100-50-50-10000/MLP_{method}/test_results_seed{seed}_batch{batch}_"

results = load_test_results(dir_path)
calculate_stats(results)
# Out:
# Constraint Violation Statistics:
# Eq violation: 9.7e+00 ± 1.3e+00
# Max eq violation: 1.4e+01
# Ineq violation: 2.2e+01 ± 9.1e-01
# Max ineq violation: 2.4e+01
#
# Optimality Gap Statistics:
# Mean opt gap: 104.185 ± 3.053
# Min opt gap: 95.411
# Max opt gap: 116.889
#
# Time Statistics:
# Total time: 0.085

# %%
import pickle

# Load the pickle file
# dir = '/home/hoang/Projects/FSNet-ls/results/convex/qp/QPProblem-100-50-50-10000/MLP_penalty/results_seed2025.pkl'
dir = '/home/hoang/Projects/FSNet-ls/results/convex/qp/QPProblem-100-50-50-10000/MLP_FSNet/results_seed2025.pkl'
with open(dir, 'rb') as f:
    qp_results = pickle.load(f)

print("Loaded QP results:")
print(type(qp_results))
if isinstance(qp_results, dict):
    print("Keys:", list(qp_results.keys()))
# Out:
# Loaded QP results:
# <class 'dict'>
# Keys: ['seed', 'method', 'config', 'timestamp', 'training_time_seconds', 'train_history', 'val_history', 'test_results', 'pytorch_version', 'device_used']

# %%
qp_results['test_results']
# Out:
# {'batch_size_comparison': {256: {'metrics': {'eq_violation_l2_max': 7.677126707783962e-09,
#     'true_objective': -36.22167771388808,
#     'ineq_violation_l1_mean': 1.350247049561286e-07,
#     'ineq_violation_l2_mean': 1.3700458529698844e-12,
#     'ineq_violation_l2_max': 2.7455092707653873e-10,
#     'objective': -36.01139702711478,
#     'solution_distance_max': 0.8267772896983836,
#     'ineq_violation_max_mean': 1.1946312128399107e-07,
#     'opt_gap_mean': 0.005803540354415214,
#     'solution_distance_mean': 0.27712124310804254,
#     'eq_violation_max_mean': 8.341353134461567e-06,
#     'opt_gap_std': 0.00011348635944246993,
#     'eq_violation_max_max': 3.144551151447136e-05,
#     'ineq_violation_l1_max': 1.569651803301486e-05,
#     'eq_violation_l2_mean': 7.394002416046755e-10,
#     'eq_violation_l1_mean': 0.00013630740202233402,
#     'eq_violation_l1_max': 0.00048021676679496335,
#     'opt_gap_max': 0.012838550334390452,
#     'solution_distance_std': 0.007498839093456391,
#     'opt_gap_min': 0.0013708589011144465,
#     'ineq_violation_max_max': 1.264628780428545e-05,
#     'total_time': 0.5442633628845215,
#     'avg_inference_time': 0.06803292036056519},
#    'batch_size': 256,
#    'memory_efficient': False},
#   512: {'metrics': {'eq_violation_l2_max': 1.2535247186450564e-08,
#     'true_objective': -36.22078747452461,
#     'ineq_violation_l1_mean': 1.5679504784533084e-07,
#     'ineq_violation_l2_mean': 1.7112737445031788e-12,
#     'ineq_violation_l2_max': 5.910031117749428e-10,
#     'objective': -36.01012101081486,
#     'solution_distance_max': 0.935449763128682,
#     'ineq_violation_max_mean': 1.3218176351859785e-07,
#     'opt_gap_mean': 0.0058143196490188275,
#     'solution_distance_mean': 0.2774072302497487,
#     'eq_violation_max_mean': 9.131835485004593e-06,
#     'opt_gap_std': 6.47475360442075e-05,
#     'eq_violation_max_max': 4.5028304355689e-05,
#     'ineq_violation_l1_max': 2.9331795369236247e-05,
#     'eq_violation_l2_mean': 8.752402542704859e-10,
#     'eq_violation_l1_mean': 0.0001490214473343839,
#     'eq_violation_l1_max': 0.0006167353839963409,
#     'opt_gap_max': 0.013489167316947291,
#     'solution_distance_std': 0.0034183226727189184,
#     'opt_gap_min': 0.0012939150525224422,
#     'ineq_violation_max_max': 2.1348197471793284e-05,
#     'total_time': 0.30562424659729004,
#     'avg_inference_time': 0.07640606164932251},
#    'batch_size': 512,
#    'memory_efficient': False}},
#  'detailed_results_all_batch_sizes': {256: [{'X': tensor([[ 0.3295, -0.1888, -0.2625,  ..., -0.2804, -0.1244, -0.3078],
#             [ 0.0994, -0.2204,  0.4094,  ...,  0.1816, -0.3008, -0.3209],
#             [ 0.2642, -0.4589, -0.4622,  ...,  0.2874, -0.4515, -0.0886],
#             ...,
#             [ 0.0809, -0.1308,  0.0685,  ...,  0.3768,  0.4702, -0.2851],
#             [-0.3952, -0.0083,  0.0499,  ..., -0.1360,  0.1820, -0.0849],
#             [ 0.3257,  0.2814, -0.0315,  ..., -0.0475, -0.4205, -0.0473]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5470, 0.4571, 0.4894,  ..., 0.5022, 0.5710, 0.5693],
#             [0.5544, 0.4615, 0.4967,  ..., 0.4964, 0.5775, 0.5688],
#             [0.5609, 0.4603, 0.4886,  ..., 0.4922, 0.5904, 0.5771],
#             ...,
#             [0.5456, 0.4555, 0.5009,  ..., 0.5022, 0.5846, 0.5805],
#             [0.5518, 0.4575, 0.4852,  ..., 0.4950, 0.5865, 0.5756],
#             [0.5571, 0.4674, 0.4939,  ..., 0.5039, 0.5800, 0.5782]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.4703, -0.4287, -0.1061,  ...,  0.0224,  0.7098,  0.6933],
#             [ 0.5439, -0.3846, -0.0328,  ..., -0.0356,  0.7750,  0.6877],
#             [ 0.6087, -0.3969, -0.1139,  ..., -0.0784,  0.9045,  0.7713],
#             ...,
#             [ 0.4559, -0.4452,  0.0085,  ...,  0.0217,  0.8461,  0.8046],
#             [ 0.5179, -0.4247, -0.1482,  ..., -0.0500,  0.8654,  0.7560],
#             [ 0.5706, -0.3264, -0.0605,  ...,  0.0391,  0.7999,  0.7825]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.4812, -0.4403, -0.1083,  ...,  0.0192,  0.6968,  0.6868],
#             [ 0.5688, -0.3884, -0.0338,  ..., -0.0380,  0.7552,  0.6903],
#             [ 0.6304, -0.3906, -0.1162,  ..., -0.0827,  0.8896,  0.7731],
#             ...,
#             [ 0.4739, -0.4454,  0.0099,  ...,  0.0213,  0.8244,  0.8117],
#             [ 0.5387, -0.4341, -0.1594,  ..., -0.0519,  0.8628,  0.7688],
#             [ 0.5945, -0.3238, -0.0632,  ...,  0.0330,  0.7833,  0.7820]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.4818, -0.4097, -0.0598,  ..., -0.0452,  0.7478,  0.6897],
#             [ 0.5974, -0.4001, -0.0452,  ..., -0.0668,  0.7660,  0.7163],
#             [ 0.6399, -0.3937, -0.1155,  ..., -0.0629,  0.9332,  0.7847],
#             ...,
#             [ 0.4590, -0.4206, -0.0206,  ..., -0.0214,  0.8548,  0.7999],
#             [ 0.5671, -0.4866, -0.1064,  ..., -0.0512,  0.8725,  0.7805],
#             [ 0.6035, -0.3894, -0.0359,  ...,  0.0014,  0.7749,  0.7569]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.02336844090266,
#      'true_objective': -36.22910220040991,
#      'opt_gap_mean': 0.005678358183803703,
#      'opt_gap_std': 0.002286360544172502,
#      'opt_gap_max': 0.015328693023519333,
#      'opt_gap_min': 0.0012359258121354413,
#      'eq_violation_l2_mean': 8.69751624822806e-10,
#      'eq_violation_l2_max': 7.2755851357579295e-09,
#      'ineq_violation_l2_mean': 6.198461420137474e-13,
#      'ineq_violation_l2_max': 1.3160327577975473e-10,
#      'eq_violation_l1_mean': 0.00014975950107300293,
#      'eq_violation_l1_max': 0.00048341986774858535,
#      'ineq_violation_l1_mean': 8.529839949644735e-08,
#      'ineq_violation_l1_max': 1.1471847095378962e-05,
#      'eq_violation_max_mean': 9.122730730966381e-06,
#      'eq_violation_max_max': 3.214499016499818e-05,
#      'ineq_violation_max_mean': 8.529839949644735e-08,
#      'ineq_violation_max_max': 1.1471847095378962e-05,
#      'solution_distance_mean': 0.27163788000961764,
#      'solution_distance_std': 0.1500042011716822,
#      'solution_distance_max': 1.1746805222483812,
#      'inference_time': 0.06784486770629883}},
#    {'X': tensor([[ 0.0380, -0.2445,  0.3731,  ..., -0.1718,  0.0444, -0.2095],
#             [ 0.1987,  0.0460, -0.2767,  ...,  0.4140,  0.3964,  0.3167],
#             [ 0.3847,  0.1639, -0.1620,  ...,  0.1553, -0.4154, -0.4571],
#             ...,
#             [ 0.0962,  0.4885,  0.0631,  ..., -0.2316, -0.1073, -0.4727],
#             [ 0.3336,  0.1498, -0.0410,  ..., -0.1908,  0.0251,  0.4679],
#             [-0.2507,  0.2466, -0.0617,  ..., -0.3863, -0.2346, -0.1645]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5543, 0.4597, 0.5018,  ..., 0.5056, 0.5696, 0.5802],
#             [0.5594, 0.4567, 0.4934,  ..., 0.5044, 0.5897, 0.5799],
#             [0.5527, 0.4608, 0.4864,  ..., 0.4972, 0.5735, 0.5796],
#             ...,
#             [0.5519, 0.4631, 0.4947,  ..., 0.5024, 0.5789, 0.5769],
#             [0.5636, 0.4639, 0.4968,  ..., 0.4983, 0.5781, 0.5700],
#             [0.5610, 0.4631, 0.4894,  ..., 0.4999, 0.5794, 0.5742]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 5.4317e-01, -4.0289e-01,  1.7943e-02,  ...,  5.5829e-02,
#               6.9600e-01,  8.0211e-01],
#             [ 5.9448e-01, -4.3348e-01, -6.5733e-02,  ...,  4.4109e-02,
#               8.9656e-01,  7.9869e-01],
#             [ 5.2670e-01, -3.9249e-01, -1.3583e-01,  ..., -2.7860e-02,
#               7.3476e-01,  7.9619e-01],
#             ...,
#             [ 5.1868e-01, -3.6947e-01, -5.2822e-02,  ...,  2.3928e-02,
#               7.8876e-01,  7.6906e-01],
#             [ 6.3597e-01, -3.6103e-01, -3.2474e-02,  ..., -1.7405e-02,
#               7.8121e-01,  7.0046e-01],
#             [ 6.0977e-01, -3.6942e-01, -1.0609e-01,  ..., -8.6603e-04,
#               7.9410e-01,  7.4206e-01]], dtype=torch.float64),
#     'Y_final': tensor([[ 0.5640, -0.4001,  0.0185,  ...,  0.0571,  0.6730,  0.8004],
#             [ 0.6114, -0.4285, -0.0645,  ...,  0.0405,  0.8852,  0.8062],
#             [ 0.5543, -0.3941, -0.1346,  ..., -0.0354,  0.7165,  0.8130],
#             ...,
#             [ 0.5354, -0.3697, -0.0506,  ...,  0.0085,  0.7671,  0.7779],
#             [ 0.6578, -0.3645, -0.0340,  ..., -0.0203,  0.7694,  0.7050],
#             [ 0.6309, -0.3678, -0.1209,  ..., -0.0088,  0.7836,  0.7532]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.4866, -0.3985, -0.0064,  ...,  0.0162,  0.7232,  0.7814],
#             [ 0.5997, -0.3942, -0.1098,  ...,  0.0618,  0.8955,  0.8151],
#             [ 0.5493, -0.4080, -0.0812,  ..., -0.1148,  0.7356,  0.7330],
#             ...,
#             [ 0.5495, -0.4022, -0.0580,  ..., -0.0176,  0.7615,  0.7911],
#             [ 0.6654, -0.3785, -0.0506,  ..., -0.0241,  0.7891,  0.7220],
#             [ 0.6091, -0.3628, -0.0899,  ..., -0.0398,  0.7630,  0.7645]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.02208650317458,
#      'true_objective': -36.2318204594123,
#      'opt_gap_mean': 0.005785423073076822,
#      'opt_gap_std': 0.00211959124922031,
#      'opt_gap_max': 0.01258567203050211,
#      'opt_gap_min': 0.001082550736423341,
#      'eq_violation_l2_mean': 7.695529220143323e-10,
#      'eq_violation_l2_max': 1.4533540930629584e-08,
#      'ineq_violation_l2_mean': 5.929276099573779e-12,
#      'ineq_violation_l2_max': 1.2852352436720192e-09,
#      'eq_violation_l1_mean': 0.0001427651095302242,
#      'eq_violation_l1_max': 0.0007201546802945227,
#      'ineq_violation_l1_mean': 3.2099617031100536e-07,
#      'ineq_violation_l1_max': 4.178054271886111e-05,
#      'eq_violation_max_mean': 8.748459496099571e-06,
#      'eq_violation_max_max': 4.2882594684046094e-05,
#      'ineq_violation_max_mean': 2.90178107886091e-07,
#      'ineq_violation_max_max': 3.525043098129288e-05,
#      'solution_distance_mean': 0.2788132724471526,
#      'solution_distance_std': 0.12455950441658584,
#      'solution_distance_max': 0.6779443659592185,
#      'inference_time': 0.06562685966491699}},
#    {'X': tensor([[-0.2158,  0.1568, -0.2451,  ...,  0.2250,  0.1164,  0.1823],
#             [ 0.3280, -0.4089, -0.1166,  ...,  0.0539,  0.1424, -0.0927],
#             [ 0.2379,  0.4909, -0.2493,  ..., -0.0056, -0.0494, -0.2504],
#             ...,
#             [-0.3089, -0.1042, -0.2321,  ...,  0.3062,  0.0940, -0.3325],
#             [ 0.1022,  0.0098,  0.0190,  ..., -0.0776,  0.1293,  0.3940],
#             [-0.3848, -0.1418, -0.4854,  ..., -0.0695,  0.4991,  0.3948]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5565, 0.4731, 0.4991,  ..., 0.5033, 0.5900, 0.5769],
#             [0.5507, 0.4593, 0.4903,  ..., 0.4952, 0.5832, 0.5733],
#             [0.5447, 0.4620, 0.4880,  ..., 0.4953, 0.5795, 0.5711],
#             ...,
#             [0.5443, 0.4589, 0.4854,  ..., 0.4955, 0.5774, 0.5756],
#             [0.5456, 0.4632, 0.4960,  ..., 0.5015, 0.5794, 0.5704],
#             [0.5579, 0.4639, 0.4903,  ..., 0.4967, 0.5773, 0.5717]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.5653, -0.2688, -0.0089,  ...,  0.0332,  0.8995,  0.7691],
#             [ 0.5073, -0.4068, -0.0972,  ..., -0.0482,  0.8320,  0.7331],
#             [ 0.4472, -0.3800, -0.1203,  ..., -0.0474,  0.7946,  0.7109],
#             ...,
#             [ 0.4429, -0.4113, -0.1459,  ..., -0.0448,  0.7744,  0.7555],
#             [ 0.4565, -0.3678, -0.0398,  ...,  0.0146,  0.7935,  0.7044],
#             [ 0.5787, -0.3615, -0.0966,  ..., -0.0326,  0.7732,  0.7169]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.5903, -0.2670, -0.0178,  ...,  0.0292,  0.8880,  0.7686],
#             [ 0.5256, -0.4138, -0.1031,  ..., -0.0467,  0.8178,  0.7374],
#             [ 0.4648, -0.3827, -0.1177,  ..., -0.0536,  0.7768,  0.7110],
#             ...,
#             [ 0.4629, -0.4169, -0.1578,  ..., -0.0558,  0.7681,  0.7709],
#             [ 0.4763, -0.3708, -0.0322,  ...,  0.0155,  0.7696,  0.7035],
#             [ 0.5990, -0.3640, -0.0976,  ..., -0.0366,  0.7617,  0.7158]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6625, -0.3450, -0.0623,  ..., -0.0361,  0.8803,  0.7753],
#             [ 0.5659, -0.4046, -0.0781,  ..., -0.0926,  0.8334,  0.7192],
#             [ 0.4592, -0.4274, -0.1130,  ..., -0.0585,  0.7883,  0.7027],
#             ...,
#             [ 0.5501, -0.4604, -0.0922,  ..., -0.0916,  0.7879,  0.7472],
#             [ 0.5146, -0.4081, -0.0360,  ..., -0.0627,  0.7218,  0.7021],
#             [ 0.6407, -0.3948, -0.0536,  ..., -0.0876,  0.7141,  0.7141]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.038791997922004,
#      'true_objective': -36.24983054697338,
#      'opt_gap_mean': 0.0058218440463830255,
#      'opt_gap_std': 0.0022194923673043094,
#      'opt_gap_max': 0.012664178125655252,
#      'opt_gap_min': 0.001381947848761025,
#      'eq_violation_l2_mean': 2.6072647418247145e-10,
#      'eq_violation_l2_max': 1.977907862344676e-09,
#      'ineq_violation_l2_mean': 1.7168062563041134e-12,
#      'ineq_violation_l2_max': 3.343526731334402e-10,
#      'eq_violation_l1_mean': 8.340538146468194e-05,
#      'eq_violation_l1_max': 0.00025003005910601353,
#      'ineq_violation_l1_mean': 1.5204755904330014e-07,
#      'ineq_violation_l1_max': 2.4147026487675305e-05,
#      'eq_violation_max_mean': 5.1084217266044125e-06,
#      'eq_violation_max_max': 1.7431880006323064e-05,
#      'ineq_violation_max_mean': 1.2362103590790596e-07,
#      'ineq_violation_max_max': 1.6869836565014396e-05,
#      'solution_distance_mean': 0.2814822976347702,
#      'solution_distance_std': 0.1357713132843213,
#      'solution_distance_max': 0.881201659403069,
#      'inference_time': 0.07175064086914062}},
#    {'X': tensor([[-0.3654, -0.0371, -0.3345,  ..., -0.0954, -0.0743, -0.1843],
#             [-0.0557,  0.2969, -0.4497,  ...,  0.4660, -0.1778,  0.4300],
#             [ 0.2032,  0.2615, -0.3558,  ..., -0.4920,  0.0319, -0.3431],
#             ...,
#             [-0.2884, -0.0351, -0.3626,  ..., -0.1920,  0.2741, -0.0130],
#             [-0.4798, -0.0168, -0.1044,  ..., -0.3413,  0.0709,  0.1981],
#             [-0.1704, -0.3317,  0.3662,  ..., -0.0037,  0.1493,  0.3838]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5520, 0.4608, 0.4900,  ..., 0.4992, 0.5884, 0.5640],
#             [0.5500, 0.4624, 0.4907,  ..., 0.4946, 0.5806, 0.5733],
#             [0.5520, 0.4643, 0.4873,  ..., 0.5003, 0.5846, 0.5711],
#             ...,
#             [0.5576, 0.4698, 0.4887,  ..., 0.4991, 0.5842, 0.5786],
#             [0.5554, 0.4662, 0.4897,  ..., 0.5048, 0.5874, 0.5680],
#             [0.5693, 0.4645, 0.4996,  ..., 0.5084, 0.5769, 0.5825]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.5203, -0.3919, -0.1005,  ..., -0.0078,  0.8838,  0.6395],
#             [ 0.5000, -0.3764, -0.0926,  ..., -0.0539,  0.8057,  0.7330],
#             [ 0.5201, -0.3574, -0.1272,  ...,  0.0033,  0.8456,  0.7107],
#             ...,
#             [ 0.5756, -0.3021, -0.1134,  ..., -0.0088,  0.8424,  0.7862],
#             [ 0.5538, -0.3380, -0.1025,  ...,  0.0484,  0.8738,  0.6802],
#             [ 0.6932, -0.3554, -0.0039,  ...,  0.0837,  0.7686,  0.8251]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.5369, -0.3969, -0.1040,  ..., -0.0147,  0.8744,  0.6466],
#             [ 0.5216, -0.3732, -0.1040,  ..., -0.0540,  0.7927,  0.7396],
#             [ 0.5401, -0.3543, -0.1331,  ...,  0.0015,  0.8307,  0.7106],
#             ...,
#             [ 0.5936, -0.3030, -0.1161,  ..., -0.0097,  0.8362,  0.7929],
#             [ 0.5771, -0.3376, -0.1115,  ...,  0.0496,  0.8603,  0.6860],
#             [ 0.7195, -0.3464, -0.0013,  ...,  0.0842,  0.7454,  0.8257]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6399, -0.4551, -0.0861,  ..., -0.0252,  0.8820,  0.7069],
#             [ 0.5520, -0.3725, -0.0672,  ..., -0.1115,  0.7913,  0.7384],
#             [ 0.5620, -0.3946, -0.0844,  ..., -0.0665,  0.8424,  0.7355],
#             ...,
#             [ 0.6385, -0.3855, -0.1021,  ..., -0.0291,  0.8509,  0.7823],
#             [ 0.6233, -0.3977, -0.0816,  ..., -0.0357,  0.8604,  0.7180],
#             [ 0.6898, -0.3619, -0.0236,  ...,  0.0483,  0.6996,  0.8181]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.00102260164461,
#      'true_objective': -36.213461139135035,
#      'opt_gap_mean': 0.0058654061434201205,
#      'opt_gap_std': 0.002009371949053791,
#      'opt_gap_max': 0.012332342726957175,
#      'opt_gap_min': 0.0017386015777439369,
#      'eq_violation_l2_mean': 8.279235628408926e-10,
#      'eq_violation_l2_max': 9.289935126890742e-09,
#      'ineq_violation_l2_mean': 9.561916358652198e-14,
#      'ineq_violation_l2_max': 9.759219825715101e-12,
#      'eq_violation_l1_mean': 0.00014338620356875936,
#      'eq_violation_l1_max': 0.0005404531164227054,
#      'ineq_violation_l1_mean': 3.3389676440398475e-08,
#      'ineq_violation_l1_max': 3.1239750040157332e-06,
#      'eq_violation_max_mean': 8.854075888105238e-06,
#      'eq_violation_max_max': 3.0153155021660216e-05,
#      'ineq_violation_max_mean': 3.3389676440398475e-08,
#      'ineq_violation_max_max': 3.1239750040157332e-06,
#      'solution_distance_mean': 0.2837679301268839,
#      'solution_distance_std': 0.13184158301525675,
#      'solution_distance_max': 0.7112740665288996,
#      'inference_time': 0.06656265258789062}},
#    {'X': tensor([[ 0.0836, -0.0738, -0.2289,  ...,  0.4518, -0.0338, -0.0774],
#             [ 0.4103, -0.3607,  0.4736,  ..., -0.1742, -0.4852, -0.4199],
#             [ 0.0411, -0.2509,  0.2036,  ..., -0.4614,  0.4254,  0.1766],
#             ...,
#             [-0.4344,  0.2249,  0.3525,  ...,  0.2334, -0.2904, -0.0968],
#             [-0.1451, -0.1199, -0.3290,  ...,  0.1057,  0.4835,  0.0588],
#             [ 0.4431,  0.0882, -0.3303,  ..., -0.2277, -0.3915,  0.0963]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5638, 0.4502, 0.4913,  ..., 0.5022, 0.5757, 0.5811],
#             [0.5466, 0.4658, 0.4916,  ..., 0.4975, 0.5815, 0.5663],
#             [0.5583, 0.4596, 0.4970,  ..., 0.5046, 0.5846, 0.5776],
#             ...,
#             [0.5549, 0.4673, 0.4943,  ..., 0.5095, 0.5850, 0.5713],
#             [0.5537, 0.4573, 0.5023,  ..., 0.4940, 0.5888, 0.5746],
#             [0.5579, 0.4525, 0.4931,  ..., 0.4945, 0.5734, 0.5718]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.6378, -0.4983, -0.0870,  ...,  0.0217,  0.7569,  0.8107],
#             [ 0.4656, -0.3424, -0.0841,  ..., -0.0247,  0.8148,  0.6628],
#             [ 0.5830, -0.4036, -0.0303,  ...,  0.0460,  0.8456,  0.7756],
#             ...,
#             [ 0.5490, -0.3267, -0.0565,  ...,  0.0952,  0.8505,  0.7128],
#             [ 0.5368, -0.4273,  0.0230,  ..., -0.0601,  0.8884,  0.7463],
#             [ 0.5790, -0.4750, -0.0686,  ..., -0.0548,  0.7340,  0.7177]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.6677, -0.4988, -0.0973,  ...,  0.0129,  0.7432,  0.8174],
#             [ 0.4816, -0.3381, -0.0857,  ..., -0.0280,  0.7932,  0.6625],
#             [ 0.6096, -0.3999, -0.0294,  ...,  0.0342,  0.8285,  0.7679],
#             ...,
#             [ 0.5625, -0.3289, -0.0627,  ...,  0.0943,  0.8436,  0.7151],
#             [ 0.5480, -0.4300,  0.0308,  ..., -0.0704,  0.8664,  0.7485],
#             [ 0.6058, -0.4690, -0.0783,  ..., -0.0649,  0.7152,  0.7228]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6572, -0.4821, -0.0718,  ...,  0.0229,  0.7709,  0.7789],
#             [ 0.4950, -0.3780, -0.0554,  ..., -0.1333,  0.7055,  0.6678],
#             [ 0.5792, -0.4134, -0.0454,  ...,  0.0136,  0.8589,  0.7530],
#             ...,
#             [ 0.5680, -0.3985, -0.0729,  ...,  0.0738,  0.8486,  0.7364],
#             [ 0.5675, -0.4542, -0.0165,  ..., -0.0755,  0.8507,  0.7059],
#             [ 0.5753, -0.4023, -0.0571,  ..., -0.0773,  0.7020,  0.7478]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.00763575731349,
#      'true_objective': -36.223539059551044,
#      'opt_gap_mean': 0.005959069883853833,
#      'opt_gap_std': 0.002186926533315816,
#      'opt_gap_max': 0.013190766935191623,
#      'opt_gap_min': 0.001576391478864198,
#      'eq_violation_l2_mean': 9.390899204416578e-10,
#      'eq_violation_l2_max': 9.862362513768252e-09,
#      'ineq_violation_l2_mean': 1.2605414158984544e-12,
#      'ineq_violation_l2_max': 2.6089162677754053e-10,
#      'eq_violation_l1_mean': 0.0001554748805491088,
#      'eq_violation_l1_max': 0.0005290090740640765,
#      'ineq_violation_l1_mean': 1.69214091759462e-07,
#      'ineq_violation_l1_max': 2.2538507725045065e-05,
#      'eq_violation_max_mean': 9.459095818107675e-06,
#      'eq_violation_max_max': 4.628763036884642e-05,
#      'ineq_violation_max_mean': 1.180152263552392e-07,
#      'ineq_violation_max_max': 1.3126598949142476e-05,
#      'solution_distance_mean': 0.2843844315206105,
#      'solution_distance_std': 0.12843250197727274,
#      'solution_distance_max': 0.9202200652278907,
#      'inference_time': 0.06833553314208984}},
#    {'X': tensor([[ 0.1238, -0.2948,  0.0814,  ...,  0.2466, -0.1242,  0.1523],
#             [ 0.3126,  0.2139,  0.1994,  ..., -0.0887,  0.2239, -0.0659],
#             [ 0.2110, -0.3438, -0.1061,  ..., -0.2237, -0.1342, -0.0228],
#             ...,
#             [-0.3033, -0.1586,  0.4849,  ...,  0.0038,  0.2022, -0.2240],
#             [-0.1138,  0.3131, -0.0614,  ...,  0.2921, -0.1815, -0.2940],
#             [ 0.2898,  0.2141,  0.1138,  ..., -0.1787, -0.3152, -0.0300]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5524, 0.4528, 0.4975,  ..., 0.4843, 0.5891, 0.5677],
#             [0.5568, 0.4589, 0.4989,  ..., 0.4930, 0.5755, 0.5763],
#             [0.5527, 0.4624, 0.4974,  ..., 0.5007, 0.5828, 0.5731],
#             ...,
#             [0.5520, 0.4632, 0.4933,  ..., 0.5118, 0.5752, 0.5677],
#             [0.5485, 0.4691, 0.4887,  ..., 0.5085, 0.5842, 0.5724],
#             [0.5541, 0.4608, 0.4968,  ..., 0.5107, 0.5753, 0.5605]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.5237, -0.4718, -0.0248,  ..., -0.1567,  0.8908,  0.6768],
#             [ 0.5683, -0.4114, -0.0107,  ..., -0.0703,  0.7551,  0.7635],
#             [ 0.5268, -0.3762, -0.0257,  ...,  0.0069,  0.8285,  0.7306],
#             ...,
#             [ 0.5198, -0.3681, -0.0665,  ...,  0.1176,  0.7519,  0.6770],
#             [ 0.4848, -0.3091, -0.1130,  ...,  0.0854,  0.8419,  0.7242],
#             [ 0.5409, -0.3919, -0.0322,  ...,  0.1072,  0.7528,  0.6049]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.5413, -0.4691, -0.0182,  ..., -0.1710,  0.8760,  0.6795],
#             [ 0.5927, -0.4078, -0.0158,  ..., -0.0771,  0.7385,  0.7677],
#             [ 0.5422, -0.3731, -0.0305,  ...,  0.0098,  0.8086,  0.7408],
#             ...,
#             [ 0.5408, -0.3810, -0.0712,  ...,  0.1101,  0.7359,  0.6946],
#             [ 0.5025, -0.3019, -0.1134,  ...,  0.0803,  0.8239,  0.7266],
#             [ 0.5594, -0.3975, -0.0378,  ...,  0.1019,  0.7440,  0.6065]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.5610, -0.4430, -0.0515,  ..., -0.1459,  0.9195,  0.6785],
#             [ 0.5424, -0.3806, -0.0123,  ..., -0.1088,  0.7402,  0.7136],
#             [ 0.5722, -0.3867, -0.0245,  ..., -0.0422,  0.8412,  0.7564],
#             ...,
#             [ 0.5909, -0.4267, -0.0708,  ...,  0.0255,  0.7535,  0.7225],
#             [ 0.5565, -0.3793, -0.0922,  ...,  0.0038,  0.7994,  0.7687],
#             [ 0.5696, -0.4274, -0.0459,  ...,  0.0407,  0.7679,  0.6347]],
#            dtype=torch.float64),
#     'metrics': {'objective': -35.982670060812026,
#      'true_objective': -36.194372691668185,
#      'opt_gap_mean': 0.005846840614242541,
#      'opt_gap_std': 0.001966281818502292,
#      'opt_gap_max': 0.012857873802374008,
#      'opt_gap_min': 0.0017143807796324774,
#      'eq_violation_l2_mean': 8.479447725978863e-10,
#      'eq_violation_l2_max': 5.993319672072317e-09,
#      'ineq_violation_l2_mean': 1.7367946961546507e-13,
#      'ineq_violation_l2_max': 1.9279316675385758e-11,
#      'eq_violation_l1_mean': 0.00014709763505853964,
#      'eq_violation_l1_max': 0.00043186376743288915,
#      'ineq_violation_l1_mean': 6.476175342870483e-08,
#      'ineq_violation_l1_max': 4.390821867872319e-06,
#      'eq_violation_max_mean': 8.881081132197428e-06,
#      'eq_violation_max_max': 2.817277515868022e-05,
#      'ineq_violation_max_mean': 6.476175342870483e-08,
#      'ineq_violation_max_max': 4.390821867872319e-06,
#      'solution_distance_mean': 0.2718981200481516,
#      'solution_distance_std': 0.1202919804593477,
#      'solution_distance_max': 0.8426119010374882,
#      'inference_time': 0.06927347183227539}},
#    {'X': tensor([[ 0.1899,  0.2743, -0.3587,  ..., -0.0029, -0.1764, -0.0745],
#             [ 0.2237, -0.3849, -0.0596,  ..., -0.3043,  0.3745, -0.4746],
#             [-0.1819,  0.3281,  0.4692,  ..., -0.2874,  0.0483, -0.4581],
#             ...,
#             [-0.0183, -0.3013, -0.1773,  ..., -0.1064,  0.1841, -0.4883],
#             [-0.2397, -0.3194, -0.3405,  ...,  0.4428, -0.4161,  0.4465],
#             [ 0.2586,  0.2915, -0.2257,  ..., -0.0221,  0.1639, -0.1978]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5602, 0.4623, 0.4879,  ..., 0.4962, 0.5812, 0.5788],
#             [0.5549, 0.4596, 0.4895,  ..., 0.4959, 0.5785, 0.5651],
#             [0.5582, 0.4603, 0.4962,  ..., 0.5077, 0.5718, 0.5806],
#             ...,
#             [0.5534, 0.4562, 0.4898,  ..., 0.4964, 0.5871, 0.5814],
#             [0.5500, 0.4619, 0.4906,  ..., 0.5039, 0.5934, 0.5725],
#             [0.5609, 0.4686, 0.4850,  ..., 0.5054, 0.5846, 0.5796]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.6024, -0.3774, -0.1207,  ..., -0.0377,  0.8124,  0.7877],
#             [ 0.5487, -0.4042, -0.1053,  ..., -0.0407,  0.7853,  0.6506],
#             [ 0.5817, -0.3969, -0.0381,  ...,  0.0768,  0.7182,  0.8057],
#             ...,
#             [ 0.5339, -0.4382, -0.1016,  ..., -0.0355,  0.8706,  0.8137],
#             [ 0.5000, -0.3812, -0.0941,  ...,  0.0388,  0.9344,  0.7247],
#             [ 0.6091, -0.3138, -0.1504,  ...,  0.0545,  0.8462,  0.7964]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.6169, -0.3804, -0.1235,  ..., -0.0479,  0.7960,  0.7947],
#             [ 0.5711, -0.4099, -0.1097,  ..., -0.0520,  0.7780,  0.6583],
#             [ 0.5967, -0.4009, -0.0529,  ...,  0.0677,  0.7122,  0.8158],
#             ...,
#             [ 0.5547, -0.4437, -0.1122,  ..., -0.0407,  0.8639,  0.8228],
#             [ 0.5126, -0.3869, -0.1015,  ...,  0.0345,  0.9285,  0.7275],
#             [ 0.6256, -0.3140, -0.1568,  ...,  0.0533,  0.8350,  0.8004]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6723, -0.4200, -0.0699,  ..., -0.0512,  0.7855,  0.7566],
#             [ 0.6239, -0.4474, -0.1097,  ..., -0.0609,  0.8310,  0.6785],
#             [ 0.5752, -0.4336, -0.0454,  ...,  0.0235,  0.6929,  0.7876],
#             ...,
#             [ 0.5571, -0.4279, -0.0611,  ..., -0.0649,  0.8549,  0.7851],
#             [ 0.5395, -0.3996, -0.0770,  ..., -0.0382,  0.9263,  0.7587],
#             [ 0.6549, -0.3880, -0.0951,  ...,  0.0010,  0.8300,  0.7703]],
#            dtype=torch.float64),
#     'metrics': {'objective': -35.967969988738844,
#      'true_objective': -36.181225218256785,
#      'opt_gap_mean': 0.005889963660954525,
#      'opt_gap_std': 0.0022394100771599376,
#      'opt_gap_max': 0.01277127137823944,
#      'opt_gap_min': 0.0011185598368203757,
#      'eq_violation_l2_mean': 8.355227148526938e-10,
#      'eq_violation_l2_max': 7.71284388546214e-09,
#      'ineq_violation_l2_mean': 3.579906845259591e-13,
#      'ineq_violation_l2_max': 3.960929424664164e-11,
#      'eq_violation_l1_mean': 0.0001475609225506823,
#      'eq_violation_l1_max': 0.0004891877189219286,
#      'ineq_violation_l1_mean': 1.0083679771732967e-07,
#      'ineq_violation_l1_max': 7.364109957386233e-06,
#      'eq_violation_max_mean': 9.23583640664836e-06,
#      'eq_violation_max_max': 3.1013220102606154e-05,
#      'ineq_violation_max_mean': 9.621714383567515e-08,
#      'ineq_violation_max_max': 6.181478563682674e-06,
#      'solution_distance_mean': 0.2832367757801,
#      'solution_distance_std': 0.12837305027428578,
#      'solution_distance_max': 0.7656894402316242,
#      'inference_time': 0.06662917137145996}},
#    {'X': tensor([[ 0.1902,  0.2182, -0.0466,  ..., -0.2214,  0.1360,  0.0570],
#             [ 0.2365,  0.4566, -0.3929,  ..., -0.4120, -0.1843, -0.0729],
#             [-0.4384,  0.0168,  0.3029,  ...,  0.1116,  0.0014, -0.2591],
#             ...,
#             [ 0.3476,  0.4318,  0.3167,  ..., -0.4888,  0.1843, -0.3251],
#             [ 0.3908,  0.4081,  0.4825,  ..., -0.2938, -0.3952,  0.3441],
#             [-0.1088, -0.1651,  0.1260,  ..., -0.0416, -0.2738,  0.3310]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5568, 0.4644, 0.4938,  ..., 0.4994, 0.5874, 0.5742],
#             [0.5502, 0.4588, 0.4979,  ..., 0.5001, 0.5754, 0.5794],
#             [0.5590, 0.4607, 0.4843,  ..., 0.5107, 0.5797, 0.5826],
#             ...,
#             [0.5670, 0.4644, 0.4936,  ..., 0.4972, 0.5758, 0.5795],
#             [0.5548, 0.4566, 0.5036,  ..., 0.5020, 0.5856, 0.5570],
#             [0.5580, 0.4672, 0.4997,  ..., 0.5007, 0.5932, 0.5635]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.5678, -0.3555, -0.0618,  ..., -0.0064,  0.8741,  0.7420],
#             [ 0.5025, -0.4121, -0.0213,  ...,  0.0013,  0.7537,  0.7943],
#             [ 0.5904, -0.3930, -0.1567,  ...,  0.1068,  0.7974,  0.8255],
#             ...,
#             [ 0.6701, -0.3564, -0.0640,  ..., -0.0280,  0.7585,  0.7951],
#             [ 0.5477, -0.4342,  0.0363,  ...,  0.0198,  0.8560,  0.5702],
#             [ 0.5796, -0.3279, -0.0030,  ...,  0.0074,  0.9325,  0.6346]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.5828, -0.3562, -0.0563,  ..., -0.0123,  0.8522,  0.7449],
#             [ 0.5251, -0.4125, -0.0257,  ..., -0.0080,  0.7354,  0.7972],
#             [ 0.6095, -0.3887, -0.1630,  ...,  0.1011,  0.7890,  0.8305],
#             ...,
#             [ 0.6900, -0.3522, -0.0702,  ..., -0.0386,  0.7535,  0.7935],
#             [ 0.5594, -0.4346,  0.0405,  ...,  0.0129,  0.8330,  0.5658],
#             [ 0.5972, -0.3259, -0.0062,  ...,  0.0128,  0.9151,  0.6412]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6001, -0.4166, -0.0381,  ..., -0.0384,  0.8289,  0.7604],
#             [ 0.4597, -0.4088,  0.0112,  ..., -0.0736,  0.7464,  0.7531],
#             [ 0.5987, -0.4222, -0.1025,  ...,  0.0517,  0.7889,  0.7930],
#             ...,
#             [ 0.6945, -0.3890, -0.0254,  ..., -0.0129,  0.7588,  0.7945],
#             [ 0.5084, -0.3939, -0.0136,  ..., -0.0478,  0.8260,  0.6058],
#             [ 0.6295, -0.3372, -0.0345,  ..., -0.0632,  0.9307,  0.6404]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.04763086641007,
#      'true_objective': -36.25007039569796,
#      'opt_gap_mean': 0.005581417229587141,
#      'opt_gap_std': 0.002043958853719521,
#      'opt_gap_max': 0.01097760465268467,
#      'opt_gap_min': 0.0011185131385347755,
#      'eq_violation_l2_mean': 5.646899410846634e-10,
#      'eq_violation_l2_max': 4.771518535346059e-09,
#      'ineq_violation_l2_mean': 8.066075922410336e-13,
#      'ineq_violation_l2_max': 1.1567676650181277e-10,
#      'eq_violation_l1_mean': 0.000121009582383673,
#      'eq_violation_l1_max': 0.00039761585036898577,
#      'ineq_violation_l1_mean': 1.5365319145238106e-07,
#      'ineq_violation_l1_max': 1.075531340788416e-05,
#      'eq_violation_max_mean': 7.321123876963462e-06,
#      'eq_violation_max_max': 2.347784660861052e-05,
#      'ineq_violation_max_mean': 1.4422362692146663e-07,
#      'ineq_violation_max_max': 1.075531340788416e-05,
#      'solution_distance_mean': 0.2617492372970539,
#      'solution_distance_std': 0.11147645777007448,
#      'solution_distance_max': 0.6405962969504979,
#      'inference_time': 0.06824016571044922}}],
#   512: [{'X': tensor([[ 0.3295, -0.1888, -0.2625,  ..., -0.2804, -0.1244, -0.3078],
#             [ 0.0994, -0.2204,  0.4094,  ...,  0.1816, -0.3008, -0.3209],
#             [ 0.2642, -0.4589, -0.4622,  ...,  0.2874, -0.4515, -0.0886],
#             ...,
#             [ 0.0962,  0.4885,  0.0631,  ..., -0.2316, -0.1073, -0.4727],
#             [ 0.3336,  0.1498, -0.0410,  ..., -0.1908,  0.0251,  0.4679],
#             [-0.2507,  0.2466, -0.0617,  ..., -0.3863, -0.2346, -0.1645]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5470, 0.4571, 0.4894,  ..., 0.5022, 0.5710, 0.5693],
#             [0.5544, 0.4615, 0.4967,  ..., 0.4964, 0.5775, 0.5688],
#             [0.5609, 0.4603, 0.4886,  ..., 0.4922, 0.5904, 0.5771],
#             ...,
#             [0.5519, 0.4631, 0.4947,  ..., 0.5024, 0.5789, 0.5769],
#             [0.5636, 0.4639, 0.4968,  ..., 0.4983, 0.5781, 0.5700],
#             [0.5610, 0.4631, 0.4894,  ..., 0.4999, 0.5794, 0.5742]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 4.7026e-01, -4.2872e-01, -1.0614e-01,  ...,  2.2379e-02,
#               7.0984e-01,  6.9326e-01],
#             [ 5.4388e-01, -3.8462e-01, -3.2826e-02,  ..., -3.5610e-02,
#               7.7498e-01,  6.8768e-01],
#             [ 6.0870e-01, -3.9692e-01, -1.1390e-01,  ..., -7.8379e-02,
#               9.0446e-01,  7.7128e-01],
#             ...,
#             [ 5.1868e-01, -3.6947e-01, -5.2822e-02,  ...,  2.3928e-02,
#               7.8876e-01,  7.6906e-01],
#             [ 6.3597e-01, -3.6103e-01, -3.2474e-02,  ..., -1.7405e-02,
#               7.8121e-01,  7.0046e-01],
#             [ 6.0977e-01, -3.6942e-01, -1.0609e-01,  ..., -8.6603e-04,
#               7.9410e-01,  7.4206e-01]], dtype=torch.float64),
#     'Y_final': tensor([[ 0.4812, -0.4403, -0.1083,  ...,  0.0192,  0.6968,  0.6868],
#             [ 0.5688, -0.3884, -0.0338,  ..., -0.0380,  0.7552,  0.6903],
#             [ 0.6304, -0.3906, -0.1162,  ..., -0.0827,  0.8896,  0.7731],
#             ...,
#             [ 0.5354, -0.3697, -0.0506,  ...,  0.0085,  0.7671,  0.7779],
#             [ 0.6578, -0.3645, -0.0340,  ..., -0.0203,  0.7694,  0.7050],
#             [ 0.6309, -0.3678, -0.1209,  ..., -0.0088,  0.7836,  0.7532]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.4818, -0.4097, -0.0598,  ..., -0.0452,  0.7478,  0.6897],
#             [ 0.5974, -0.4001, -0.0452,  ..., -0.0668,  0.7660,  0.7163],
#             [ 0.6399, -0.3937, -0.1155,  ..., -0.0629,  0.9332,  0.7847],
#             ...,
#             [ 0.5495, -0.4022, -0.0580,  ..., -0.0176,  0.7615,  0.7911],
#             [ 0.6654, -0.3785, -0.0506,  ..., -0.0241,  0.7891,  0.7220],
#             [ 0.6091, -0.3628, -0.0899,  ..., -0.0398,  0.7630,  0.7645]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.02272746823522,
#      'true_objective': -36.23046132991111,
#      'opt_gap_mean': 0.005731890734246154,
#      'opt_gap_std': 0.0022030470979273755,
#      'opt_gap_max': 0.015328693270268423,
#      'opt_gap_min': 0.001082551855184542,
#      'eq_violation_l2_mean': 8.258410590529914e-10,
#      'eq_violation_l2_max': 1.457580806939823e-08,
#      'ineq_violation_l2_mean': 3.2800054209627783e-12,
#      'ineq_violation_l2_max': 1.2872922594234559e-09,
#      'eq_violation_l1_mean': 0.00014670862365396908,
#      'eq_violation_l1_max': 0.0007213683345886519,
#      'ineq_violation_l1_mean': 2.0448929264303695e-07,
#      'ineq_violation_l1_max': 4.1831513260426334e-05,
#      'eq_violation_max_mean': 8.962871802092819e-06,
#      'eq_violation_max_max': 4.294075018540511e-05,
#      'ineq_violation_max_mean': 1.8898722740044727e-07,
#      'ineq_violation_max_max': 3.5274630342918556e-05,
#      'solution_distance_mean': 0.27522557622771293,
#      'solution_distance_std': 0.13778194378398154,
#      'solution_distance_max': 1.1746805222406036,
#      'inference_time': 0.07714009284973145}},
#    {'X': tensor([[-0.2158,  0.1568, -0.2451,  ...,  0.2250,  0.1164,  0.1823],
#             [ 0.3280, -0.4089, -0.1166,  ...,  0.0539,  0.1424, -0.0927],
#             [ 0.2379,  0.4909, -0.2493,  ..., -0.0056, -0.0494, -0.2504],
#             ...,
#             [-0.2884, -0.0351, -0.3626,  ..., -0.1920,  0.2741, -0.0130],
#             [-0.4798, -0.0168, -0.1044,  ..., -0.3413,  0.0709,  0.1981],
#             [-0.1704, -0.3317,  0.3662,  ..., -0.0037,  0.1493,  0.3838]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5565, 0.4731, 0.4991,  ..., 0.5033, 0.5900, 0.5769],
#             [0.5507, 0.4593, 0.4903,  ..., 0.4952, 0.5832, 0.5733],
#             [0.5447, 0.4620, 0.4880,  ..., 0.4953, 0.5795, 0.5711],
#             ...,
#             [0.5576, 0.4698, 0.4887,  ..., 0.4991, 0.5842, 0.5786],
#             [0.5554, 0.4662, 0.4897,  ..., 0.5048, 0.5874, 0.5680],
#             [0.5693, 0.4645, 0.4996,  ..., 0.5084, 0.5769, 0.5825]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.5653, -0.2688, -0.0089,  ...,  0.0332,  0.8995,  0.7691],
#             [ 0.5073, -0.4068, -0.0972,  ..., -0.0482,  0.8320,  0.7331],
#             [ 0.4472, -0.3800, -0.1203,  ..., -0.0474,  0.7946,  0.7109],
#             ...,
#             [ 0.5756, -0.3021, -0.1134,  ..., -0.0088,  0.8424,  0.7862],
#             [ 0.5538, -0.3380, -0.1025,  ...,  0.0484,  0.8738,  0.6802],
#             [ 0.6932, -0.3554, -0.0039,  ...,  0.0837,  0.7686,  0.8251]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.5903, -0.2670, -0.0178,  ...,  0.0292,  0.8880,  0.7686],
#             [ 0.5256, -0.4138, -0.1031,  ..., -0.0467,  0.8178,  0.7374],
#             [ 0.4648, -0.3827, -0.1177,  ..., -0.0536,  0.7768,  0.7110],
#             ...,
#             [ 0.5936, -0.3030, -0.1161,  ..., -0.0097,  0.8362,  0.7929],
#             [ 0.5771, -0.3376, -0.1115,  ...,  0.0496,  0.8603,  0.6860],
#             [ 0.7195, -0.3464, -0.0013,  ...,  0.0842,  0.7454,  0.8257]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6625, -0.3450, -0.0623,  ..., -0.0361,  0.8803,  0.7753],
#             [ 0.5659, -0.4046, -0.0781,  ..., -0.0926,  0.8334,  0.7192],
#             [ 0.4592, -0.4274, -0.1130,  ..., -0.0585,  0.7883,  0.7027],
#             ...,
#             [ 0.6385, -0.3855, -0.1021,  ..., -0.0291,  0.8509,  0.7823],
#             [ 0.6233, -0.3977, -0.0816,  ..., -0.0357,  0.8604,  0.7180],
#             [ 0.6898, -0.3619, -0.0236,  ...,  0.0483,  0.6996,  0.8181]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.01990779412729,
#      'true_objective': -36.231645843054196,
#      'opt_gap_mean': 0.005843611485719184,
#      'opt_gap_std': 0.0021150714575900145,
#      'opt_gap_max': 0.012664010078507404,
#      'opt_gap_min': 0.001382045670858608,
#      'eq_violation_l2_mean': 9.252347459990781e-10,
#      'eq_violation_l2_max': 1.6728956410270814e-08,
#      'ineq_violation_l2_mean': 1.4598742700161322e-12,
#      'ineq_violation_l2_max': 5.034068525776432e-10,
#      'eq_violation_l1_mean': 0.0001498681665570622,
#      'eq_violation_l1_max': 0.000686780245863903,
#      'ineq_violation_l1_mean': 1.4360312529035357e-07,
#      'ineq_violation_l1_max': 3.533763362995046e-05,
#      'eq_violation_max_mean': 9.212516548488019e-06,
#      'eq_violation_max_max': 5.539430371506726e-05,
#      'ineq_violation_max_mean': 9.879325538718342e-08,
#      'ineq_violation_max_max': 1.9243635065002707e-05,
#      'solution_distance_mean': 0.2826251137817882,
#      'solution_distance_std': 0.13369476353786885,
#      'solution_distance_max': 0.8812016595516295,
#      'inference_time': 0.07740545272827148}},
#    {'X': tensor([[ 0.0836, -0.0738, -0.2289,  ...,  0.4518, -0.0338, -0.0774],
#             [ 0.4103, -0.3607,  0.4736,  ..., -0.1742, -0.4852, -0.4199],
#             [ 0.0411, -0.2509,  0.2036,  ..., -0.4614,  0.4254,  0.1766],
#             ...,
#             [-0.3033, -0.1586,  0.4849,  ...,  0.0038,  0.2022, -0.2240],
#             [-0.1138,  0.3131, -0.0614,  ...,  0.2921, -0.1815, -0.2940],
#             [ 0.2898,  0.2141,  0.1138,  ..., -0.1787, -0.3152, -0.0300]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5638, 0.4502, 0.4913,  ..., 0.5022, 0.5757, 0.5811],
#             [0.5466, 0.4658, 0.4916,  ..., 0.4975, 0.5815, 0.5663],
#             [0.5583, 0.4596, 0.4970,  ..., 0.5046, 0.5846, 0.5776],
#             ...,
#             [0.5520, 0.4632, 0.4933,  ..., 0.5118, 0.5752, 0.5677],
#             [0.5485, 0.4691, 0.4887,  ..., 0.5085, 0.5842, 0.5724],
#             [0.5541, 0.4608, 0.4968,  ..., 0.5107, 0.5753, 0.5605]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.6378, -0.4983, -0.0870,  ...,  0.0217,  0.7569,  0.8107],
#             [ 0.4656, -0.3424, -0.0841,  ..., -0.0247,  0.8148,  0.6628],
#             [ 0.5830, -0.4036, -0.0303,  ...,  0.0460,  0.8456,  0.7756],
#             ...,
#             [ 0.5198, -0.3681, -0.0665,  ...,  0.1176,  0.7519,  0.6770],
#             [ 0.4848, -0.3091, -0.1130,  ...,  0.0854,  0.8419,  0.7242],
#             [ 0.5409, -0.3919, -0.0322,  ...,  0.1072,  0.7528,  0.6049]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.6677, -0.4988, -0.0973,  ...,  0.0129,  0.7432,  0.8174],
#             [ 0.4816, -0.3381, -0.0857,  ..., -0.0280,  0.7932,  0.6625],
#             [ 0.6096, -0.3999, -0.0294,  ...,  0.0342,  0.8285,  0.7679],
#             ...,
#             [ 0.5408, -0.3810, -0.0712,  ...,  0.1101,  0.7359,  0.6946],
#             [ 0.5025, -0.3019, -0.1134,  ...,  0.0803,  0.8239,  0.7266],
#             [ 0.5594, -0.3975, -0.0378,  ...,  0.1019,  0.7440,  0.6065]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6572, -0.4821, -0.0718,  ...,  0.0229,  0.7709,  0.7789],
#             [ 0.4950, -0.3780, -0.0554,  ..., -0.1333,  0.7055,  0.6678],
#             [ 0.5792, -0.4134, -0.0454,  ...,  0.0136,  0.8589,  0.7530],
#             ...,
#             [ 0.5909, -0.4267, -0.0708,  ...,  0.0255,  0.7535,  0.7225],
#             [ 0.5565, -0.3793, -0.0922,  ...,  0.0038,  0.7994,  0.7687],
#             [ 0.5696, -0.4274, -0.0459,  ...,  0.0407,  0.7679,  0.6347]],
#            dtype=torch.float64),
#     'metrics': {'objective': -35.99515290594533,
#      'true_objective': -36.20895587560962,
#      'opt_gap_mean': 0.005902955335058336,
#      'opt_gap_std': 0.0020782560931893557,
#      'opt_gap_max': 0.013190767347805573,
#      'opt_gap_min': 0.0015763914149634183,
#      'eq_violation_l2_mean': 9.016464595322049e-10,
#      'eq_violation_l2_max': 9.88398172560822e-09,
#      'ineq_violation_l2_mean': 7.150583932128679e-13,
#      'ineq_violation_l2_max': 2.5896680971979695e-10,
#      'eq_violation_l1_mean': 0.0001518834980302732,
#      'eq_violation_l1_max': 0.0005295578987074712,
#      'ineq_violation_l1_mean': 1.1819248358843626e-07,
#      'ineq_violation_l1_max': 2.2428214356828846e-05,
#      'eq_violation_max_mean': 9.20509887838399e-06,
#      'eq_violation_max_max': 4.6342829464640634e-05,
#      'ineq_violation_max_mean': 9.283768069232035e-08,
#      'ineq_violation_max_max': 1.3144704249512529e-05,
#      'solution_distance_mean': 0.2781412757837578,
#      'solution_distance_std': 0.12446400616891469,
#      'solution_distance_max': 0.9202200652374624,
#      'inference_time': 0.0714271068572998}},
#    {'X': tensor([[ 0.1899,  0.2743, -0.3587,  ..., -0.0029, -0.1764, -0.0745],
#             [ 0.2237, -0.3849, -0.0596,  ..., -0.3043,  0.3745, -0.4746],
#             [-0.1819,  0.3281,  0.4692,  ..., -0.2874,  0.0483, -0.4581],
#             ...,
#             [ 0.3476,  0.4318,  0.3167,  ..., -0.4888,  0.1843, -0.3251],
#             [ 0.3908,  0.4081,  0.4825,  ..., -0.2938, -0.3952,  0.3441],
#             [-0.1088, -0.1651,  0.1260,  ..., -0.0416, -0.2738,  0.3310]],
#            dtype=torch.float64),
#     'Y_pred': tensor([[0.5602, 0.4623, 0.4879,  ..., 0.4962, 0.5812, 0.5788],
#             [0.5549, 0.4596, 0.4895,  ..., 0.4959, 0.5785, 0.5651],
#             [0.5582, 0.4603, 0.4962,  ..., 0.5077, 0.5718, 0.5806],
#             ...,
#             [0.5670, 0.4644, 0.4936,  ..., 0.4972, 0.5758, 0.5795],
#             [0.5548, 0.4566, 0.5036,  ..., 0.5020, 0.5856, 0.5570],
#             [0.5580, 0.4672, 0.4997,  ..., 0.5007, 0.5932, 0.5635]],
#            dtype=torch.float64),
#     'Y_pred_scaled': tensor([[ 0.6024, -0.3774, -0.1207,  ..., -0.0377,  0.8124,  0.7877],
#             [ 0.5487, -0.4042, -0.1053,  ..., -0.0407,  0.7853,  0.6506],
#             [ 0.5817, -0.3969, -0.0381,  ...,  0.0768,  0.7182,  0.8057],
#             ...,
#             [ 0.6701, -0.3564, -0.0640,  ..., -0.0280,  0.7585,  0.7951],
#             [ 0.5477, -0.4342,  0.0363,  ...,  0.0198,  0.8560,  0.5702],
#             [ 0.5796, -0.3279, -0.0030,  ...,  0.0074,  0.9325,  0.6346]],
#            dtype=torch.float64),
#     'Y_final': tensor([[ 0.6168, -0.3805, -0.1233,  ..., -0.0479,  0.7960,  0.7947],
#             [ 0.5710, -0.4099, -0.1097,  ..., -0.0520,  0.7779,  0.6583],
#             [ 0.5967, -0.4009, -0.0528,  ...,  0.0677,  0.7122,  0.8158],
#             ...,
#             [ 0.6899, -0.3523, -0.0701,  ..., -0.0386,  0.7535,  0.7935],
#             [ 0.5589, -0.4348,  0.0409,  ...,  0.0132,  0.8326,  0.5661],
#             [ 0.5969, -0.3265, -0.0059,  ...,  0.0130,  0.9151,  0.6411]],
#            dtype=torch.float64),
#     'Y_true': tensor([[ 0.6723, -0.4200, -0.0699,  ..., -0.0512,  0.7855,  0.7566],
#             [ 0.6239, -0.4474, -0.1097,  ..., -0.0609,  0.8310,  0.6785],
#             [ 0.5752, -0.4336, -0.0454,  ...,  0.0235,  0.6929,  0.7876],
#             ...,
#             [ 0.6945, -0.3890, -0.0254,  ..., -0.0129,  0.7588,  0.7945],
#             [ 0.5084, -0.3939, -0.0136,  ..., -0.0478,  0.8260,  0.6058],
#             [ 0.6295, -0.3372, -0.0345,  ..., -0.0632,  0.9307,  0.6404]],
#            dtype=torch.float64),
#     'metrics': {'objective': -36.00269587495162,
#      'true_objective': -36.212086849523516,
#      'opt_gap_mean': 0.005778821041051633,
#      'opt_gap_std': 0.002146265984925888,
#      'opt_gap_max': 0.012773198571207758,
#      'opt_gap_min': 0.0011346712690832007,
#      'eq_violation_l2_mean': 8.482387524976692e-10,
#      'eq_violation_l2_max': 8.952242540524985e-09,
#      'ineq_violation_l2_mean': 1.390156893820937e-12,
#      'ineq_violation_l2_max': 3.1434652537887455e-10,
#      'eq_violation_l1_mean': 0.00014762550109623124,
#      'eq_violation_l1_max': 0.0005292350568253373,
#      'ineq_violation_l1_mean': 1.6089528985949654e-07,
#      'ineq_violation_l1_max': 1.7729820229739346e-05,
#      'eq_violation_max_mean': 9.146854711053547e-06,
#      'eq_violation_max_max': 3.5435334057642986e-05,
#      'ineq_violation_max_mean': 1.4810889059444038e-07,
#      'ineq_violation_max_max': 1.7729820229739346e-05,
#      'solution_distance_mean': 0.27363695520573605,
#      'solution_distance_std': 0.12142675856397031,
#      'solution_distance_max': 0.7656968054850325,
#      'inference_time': 0.0796515941619873}}]}}
